# %%
import geopandas as gpd
import pandas as pd
df = pd.read_csv('test-lime-data.csv', index_col=0)

# %%
df.head()
# Out:
#                                        Please enter your organisations' primary contact phone number with country code.  \
# What is the name of your organisation?
# Resource Africa                                                              +27733532682
# Southern Africa Trust                                                   (+27) 11 318 1012
#
#                                        Please enter in your organisations' primary contact email.  \
# What is the name of your organisation?
# Resource Africa                                                   info@resourceafrica.net
# Southern Africa Trust                                        info@southernafricatrust.org
#
#                                        Please enter the address of your organisations' head office/ headquarters.  \
# What is the name of your organisation?
# Resource Africa                         45 Kyalami Boulevard, Kyalami Park,\nMidrand, ...
# Southern Africa Trust                   45 Kyalami Boulevard, Kyalami Business Park, M...
#
#                                        Please enter your organisations' website address and any social media links. [Main Website]  \
# What is the name of your organisation?
# Resource Africa                                             http://www.resourceafrica.net
# Southern Africa Trust                                 https://www.southernafricatrust.org
#
#                                        Please enter your organisations' website address and any social media links. [Facebook]  \
# What is the name of your organisation?
# Resource Africa                         https://www.facebook.com/theresourceafricanetwork
# Southern Africa Trust                       https://www.facebook.com/SouthernAfricaTrust/
#
#                                        Please enter your organisations' website address and any social media links. [Twitter]  \
# What is the name of your organisation?
# Resource Africa                                                          @africa_resource
# Southern Africa Trust                                 https://twitter.com/SthrnAfrcaTrust
#
#                                        Please enter your organisations' website address and any social media links. [Instagram]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                      https://www.instagram.com/southernafricatrust/
#
#                                        Please enter your organisations' website address and any social media links. [LinkedIn ]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                   https://www.linkedin.com/company/southern-afri...
#
#                                        Please enter your organisations' website address and any social media links. [Other]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                   https://www.youtube.com/channel/UCxgyETIYjz_5T...
#
#                                        Which of the following groups does your organisation primarily represent? [Business/Entrepreneur]  \
# What is the name of your organisation?
# Resource Africa                                                                        No
# Southern Africa Trust                                                                  No
#
#                                         ...  \
# What is the name of your organisation?  ...
# Resource Africa                         ...
# Southern Africa Trust                   ...
#
#                                        How often does {INSERTANS:815499X2X10} work together with {INSERTANS:815499X2X278SQ009}? [Multiple times in the last 6 months]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                                                                 Yes
#
#                                        How often does {INSERTANS:815499X2X10} work together with {INSERTANS:815499X2X278SQ009}? [Multiple times a month]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                                                                  No
#
#                                        How often does {INSERTANS:815499X2X10} work together with {INSERTANS:815499X2X278SQ009}? [Weekly]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                                                                  No
#
#                                        How often does {INSERTANS:815499X2X10} work together with {INSERTANS:815499X2X278SQ009}? [Multiple times a week]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                                                                  No
#
#                                        How often does {INSERTANS:815499X2X10} work together with {INSERTANS:815499X2X278SQ010}? [Not in the last 6 months]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                                                                  No
#
#                                        How often does {INSERTANS:815499X2X10} work together with {INSERTANS:815499X2X278SQ010}? [Once in the last 6 months]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                                                                  No
#
#                                        How often does {INSERTANS:815499X2X10} work together with {INSERTANS:815499X2X278SQ010}? [Multiple times in the last 6 months]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                                                                 Yes
#
#                                        How often does {INSERTANS:815499X2X10} work together with {INSERTANS:815499X2X278SQ010}? [Multiple times a month]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                                                                  No
#
#                                         How often does {INSERTANS:815499X2X10} work together with {INSERTANS:815499X2X278SQ010}? [Weekly]  \
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                                                                  No
#
#                                        How often does {INSERTANS:815499X2X10} work together with {INSERTANS:815499X2X278SQ010}? [Multiple times a week]
# What is the name of your organisation?
# Resource Africa                                                                       NaN
# Southern Africa Trust                                                                  No
#
# [2 rows x 331 columns]

# %%
import networkx
graph = networkx.Graph()

# %%
graph.add_nodes_from([1,2,3])
graph.add_edges_from([(1,2),(2,3)])

# %%
import matplotlib.pyplot as plt
# networkx.draw(graph)
# networkx.draw_random(graph)
# networkx.draw_circular(graph)
networkx.draw_spectral(graph)
plt.show()
